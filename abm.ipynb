# %% [markdown]
# # Recreating ABM in Python

# %%
# imports
import numpy as np
import pandas as pd

# %%
# colors for each bacteria in the graphics
colors = {"coop": "blue", "cheat": "red"}

# %% [markdown]
# ## Bacteria class (Agent)

# %%
# bacteria class (agent) - CA
class Bacteria:
    def __init__(self, energy, recombination, breed, loc):
        # int for bacteria energy
        self.energy = energy
        # boolean for if it takes part in recombination
        self.recombination = recombination
        # int for breed
        self.breed = breed
        # list of ints for location [x, y]
        self.loc = loc
        # string for the color according to the breed
        self.color = colors[breed]
    
    # method to set color based on breed
    def set_breed(self, breed):
        self.breed = breed
        self.color = colors[breed]

    # method to get possible move options
    def get_move_options(self, size):
        options = []  # to store possible move options
        # check if x-coordinate is not at left edge of grid
        if self.loc[0] != 0:
            options.append([self.loc[0] - 1, self.loc[1]])
        # check if x-coordinate is not at right edge of grid
        if self.loc[0] != size[0] - 1:
            options.append([self.loc[0] + 1, self.loc[1]])
        # check if y-coordinate is not at top edge of grid
        if self.loc[1] != 0:
            options.append([self.loc[0], self.loc[1] - 1])
        # check if y-coordinate is not at bottom edge of grid
        if self.loc[1] != size[1] - 1:
            options.append([self.loc[0], self.loc[1] + 1])
        return options

# %% [markdown]
# ## Simulation class (Model)

# %%
# simulation class - we can remove print statements, only for testing - CA
# TODO: add tracking and return of simulation data over generations
# TODO: add animation of simulation based on tracking of data over generations

# simulation class
class Sim:
    def __init__(self, 
                 start_energy, 
                 population_size, 
                 population_viscosity, 
                 recombination_cost,
                 mutation_rate, 
                 recombination_rate, 
                 percent_recombination, 
                 percent_cooperation,
                 contribution, 
                 multiplier, 
                 max_x, 
                 max_y):
        
        # attribute initialization
        self.start_energy = start_energy  # energy is consumed over time. when energy is 0, bacteria dies
        self.population_size = population_size  # when cells die, remaining cells reproduce to keep population size constant
        self.population_viscosity = population_viscosity  # no of gens each cell remains in same loc before moving to adjacent loc
        self.recombination_cost = recombination_cost  # subtracts from resources available to each cell that recombines
        self.mutation_rate = mutation_rate  # rate at which coops produce cheat offspring
        self.recombination_rate = recombination_rate  # rate at which recombs change phenotype of other cells in same loc (coops make others coop, cheats make others cheat, converted cells are also recomb)
        self.percent_recombination = percent_recombination  # initial percent of recombiners
        self.percent_cooperation = percent_cooperation  # initial percent of cooperators
        self.contribution = contribution  # all coops contribute some fitness to common pool
        self.multiplier = multiplier  # common pool value is multiplied (benefit of cooperation)
        self.max_x = max_x  # x-coordinate of grid
        self.max_y = max_y  # y-coordinate of grid
        
        # list to store bacteria
        self.bacteria = []

        # number of recombination and cooperation bacteria
        self.num_rec = int(np.round(population_size * percent_recombination))  # total population size * percent recombiners, round to nearest int
        self.num_coop = int(np.round(population_size * percent_cooperation))  # total population size * percent cooperators, round to nearest int

        np.random.seed(0)

        # randomly assign recombination and cooperation to bacteria
        index_rec = np.random.choice(population_size, self.num_rec, replace=False)
        index_coop = np.random.choice(population_size, self.num_coop, replace=False)

        # create bacteria
        for i in np.arange(population_size):
            bac = Bacteria(start_energy, True if i in index_rec else False, "coop" if i in index_coop else "cheat",
                           [np.random.choice(max_x, 1)[0], np.random.choice(max_y,1)[0]])
            self.bacteria.append(bac)
    
    # method to simulate a generation
    def simulate_gen(self, gen):
        #print("starting gen", gen)
        # coops contribute public goods at the cost of energy
        def contribute(bac):
            if bac.breed == "coop":
                bac.energy -= self.contribution  # coops lose energy
            return bac
        # apply contribute function to all bacteria
        self.bacteria = list(map(contribute, self.bacteria))

        # all cells benefit from public good
        def benefit(bac, amt):
            bac.energy += amt
            return bac
        # apply benefit function to all bacteria
        self.bacteria = list(map(benefit, self.bacteria, [(self.num_coop * self.multiplier) / len(self.bacteria)]
                                 * len(self.bacteria)))
        
        # cells lose energy
        def update_fitness(bac):
            # random energy decrease
            if np.random.choice(2, 1) == 1:
                bac.energy -= 1
            # recombiners lose additional energy
            if bac.recombination:
                bac.energy -= self.recombination_cost
            return bac
        # apply update_fitness function to all bacteria
        self.bacteria = list(map(update_fitness, self.bacteria))

        # bacteria die if energy is < 0
        alive_bac = []  # to store bacteria that are alive
        for b in self.bacteria:
            # bacteria with energy < 0 die
            if b.energy < 0:
                if b.breed == "coop":
                    self.num_coop -= 1  # decrease number of coops
                if b.recombination:
                    self.num_rec -= 1  # decrease number of recombiners
            else:
                alive_bac.append(b)  # if energy > 0, add bacteria to alive_bac list (includes cheaters)
        
        # update bacteria list
        self.bacteria = alive_bac

        # if no bacteria are left, method returns early
        if len(self.bacteria) == 0:
            return

        # reproduction
        # reproduce until population size is reached
        while len(self.bacteria) < self.population_size:
            # randomly select parent
            parent = self.bacteria[np.random.choice(len(self.bacteria), 1)[0]]
            # randomly select whether to mutate or not
            ## draw 1 sample from [0,1] array with probabilities (1-mutation_rate) and (mutation_rate)
            ## 0 means no mutation, 1 means mutation
            mutate = np.random.choice(2, 1, p=[1 - self.mutation_rate, self.mutation_rate])[0]
            # if mutation does not occur:
            if mutate == 0:  # child has same breed as parent
                breed = parent.breed 
            # if mutation occurs:
            elif parent.breed == "coop":  # if parent is coop, child is cheat
                breed = "cheat"
            else:
                breed = "coop"  # if parent is cheat, child is coop
            if breed == "coop":  # if child is coop, increase number of coops
                self.num_coop += 1
            if parent.recombination:  # if parent is recombiner, child is recombiner
                self.num_rec += 1
            # create child
            bac = Bacteria(parent.energy, parent.recombination, breed, parent.loc)
            # add child to bacteria list
            self.bacteria.append(bac)

        # conversion/recombination
        if self.num_rec != 0:
            # cells in each location
            bac_locs = {}
            # number of recombiners in each location
            bac_rec = {}

            # group bacteria by location
            for b in self.bacteria:
                # if location is already in bac_locs, append bacteria to list
                if str(b.loc) in bac_locs.keys():
                    bac_locs[str(b.loc)].append(b)
                    # if bacteria is recombiner, increase count of recombiners in location
                    if b.recombination:
                        bac_rec[str(b.loc)] += 1
                # if location is not in bac_locs, create new list with bacteria
                else:
                    # if bacteria is recombiner, set count of recombiners in location to 1
                    bac_locs[str(b.loc)] = [b]
                    if b.recombination:
                        bac_rec[str(b.loc)] = 1
                    # if bacteria is not recombiner, set count of recombiners in location to 0
                    else:
                        bac_rec[str(b.loc)] = 0

            # recombination
            for k in bac_locs.keys():
                # if no recombiners in location or all bacteria are recombiners, skip location
                if bac_rec[k] == 0 or bac_rec[k] == len(bac_locs[k]):
                    continue
                # for each bacteria in location
                for b in bac_locs[k]:
                    # if bacteria is not yet a recombiner:
                    if not b.recombination:
                        # pick whether to recombine or not for each recombiner based on recombination rate
                        recombine = np.random.choice(2, bac_rec[k], p=[1-self.recombination_rate, self.recombination_rate])
                        # if any bacteria recombine, increment number of recombiners
                        if np.sum(recombine) > 0:
                            b.recombination = True
                            self.num_rec += 1

        # movement
        ## bacteria move to adjacent location every population_viscosity generations
        if (gen + 1) % self.population_viscosity == 0:
            for b in self.bacteria:
                # use get_move_options method defined previously to get possible move options
                move_ops = b.get_move_options([self.max_x, self.max_y])
                # randomly select new location from possible move options
                b.loc = move_ops[np.random.choice(len(move_ops), 1)[0]]

    # method to simulate generations    
    def simulate(self, gens):
        #print("starting simulation")
        for g in np.arange(gens):
            self.simulate_gen(g)
            if len(self.bacteria) == 0:
                #print("all dead")
                break
            #print("***results after gen***", g)
            #for b in self.bacteria:
                #print(b.recombination)
                #print(b.breed)
                #print(b.energy)
                #print(b.loc)

# %%
# testing of current simulation code - CA
sim = Sim(10, 3, 2, 1, 0.5, 0.5, 0.5, 0.5, 1, 2, 5, 10)
print("***before***")
for b in sim.bacteria:
    print("*bac*")
    print("rec", b.recombination)
    print("breed", b.breed)
    print("energy", b.energy)
    print("loc", b.loc)
sim.simulate(10)
print("***after***")
for b in sim.bacteria:
    print("*bac*")
    print("rec", b.recombination)
    print("breed", b.breed)
    print("energy", b.energy)
    print("loc", b.loc)
# Out:
# ***before***
# *bac*
# rec False
# breed coop
# energy 10
# loc [3, 3]
# *bac*
# rec True
# breed cheat
# energy 10
# loc [1, 3]
# *bac*
# rec True
# breed coop
# energy 10
# loc [2, 4]
# ***after***
# *bac*
# rec False
# breed coop
# energy 7.333333333333338
# loc [3, 0]
# *bac*
# rec True
# breed cheat
# energy 6.333333333333339
# loc [1, 4]
# *bac*
# rec False
# breed coop
# energy 7.333333333333338
# loc [3, 0]

# %% [markdown]
# # Replicating results from Lee et al. (2023)

# %% [markdown]
# ## Compiled runs CSV

# %%
import random
import numpy as np

# Set the seed for reproducibility
random.seed(0)
np.random.seed(0)

# %%
# TODO: generate simulations accross a variety of params - YLB
# TODO: save end data in dictionary of simulation perfomances for future graphics - YLB

# every 100 runs, vary:
## rec_rate from 0.01 to 0.1 in 0.01 increments
## multiplier from 1 to 5 in 1 increments
## rec_cost from 0 to 2 in 1 increments
## stay from 1 to 3 in 1 increments
## pop-size from 5000 to 3000 to 7000

# Define the ranges for each parameter (start, end-excluded, step)
rec_rate_range = np.arange(0.01, 0.11, 0.01)
multiplier_range = np.arange(1, 6, 1)
rec_cost_range = np.arange(0, 3, 1)
stay_range = np.arange(1, 4, 1)
pop_size_range = np.arange(3000, 8000, 2000)

# Initialize a list to store the results
results = []

# Run the simulation for each combination of parameters
for pop_size in pop_size_range:
    for stay in stay_range:
        for rec_cost in rec_cost_range:
            for multiplier in multiplier_range:
                for rec_rate in rec_rate_range:
                    for run in range(1):  # 100 runs for full simulation
                        print(f"Running simulation with params: pop_size={pop_size}, stay={stay}, rec_cost={rec_cost}, multiplier={multiplier}, rec_rate={rec_rate}, run={run+1}")

                        # params are based on lee et al 2023 paper
                        sim = Sim(
                            start_energy=2,
                            population_size=pop_size,
                            population_viscosity=stay,
                            recombination_cost=rec_cost,
                            mutation_rate=0.001,
                            recombination_rate=rec_rate,
                            percent_recombination=0.5,
                            percent_cooperation=0,
                            contribution=1,
                            multiplier=multiplier,
                            max_x=5,  # 32 in paper
                            max_y=5  # 32 in paper
                        )

                        # Run the simulation for 500 generations
                        sim.simulate(10)  # 500 gens for full simulation
                        print(f"Completed simulation for params: pop_size={pop_size}, stay={stay}, rec_cost={rec_cost}, multiplier={multiplier}, rec_rate={rec_rate}, run={run+1}")

                        # Collect the results
                        result = {
                            # 5 parameters defined at the start of each run
                            'pop-size': pop_size,  # population size
                            'rec_cost': rec_cost,  # fitness cost of recombiners
                            'multiplier': multiplier,  # cooperation benefit multiplier
                            'stay': stay,  # population viscosity
                            'rec_rate': rec_rate,  # recombination rate

                            # 4 dependent variables recorded at the end of each run
                            'count As': sum(1 for b in sim.bacteria if b.breed == 'coop'),  # population size of cooperating cells
                            'count Ss': sum(1 for b in sim.bacteria if b.breed == 'cheat'),  # population of cheating cells
                            'count As with [recomb = 1] ': sum(1 for b in sim.bacteria if b.breed == 'coop' and b.recombination),  # population of cooperating recombining cells
                            'count Ss with [recomb = 1]': sum(1 for b in sim.bacteria if b.breed == 'cheat' and b.recombination)  # population of cheating recombining cells
                        }
                        results.append(result)
                        print(f"Results collected for params: pop_size={pop_size}, stay={stay}, rec_cost={rec_cost}, multiplier={multiplier}, rec_rate={rec_rate}, run={run+1}")

print("All simulations completed. Converting results to DataFrame...")

# Convert the results to a DataFrame
df_results = pd.DataFrame(results)

# Save the results to a CSV file
df_results.to_csv('simulation_results.csv', index=False)

print("Results saved to 'simulation_results.csv'. Here is a preview:")
# Display first few rows
print(df_results.head())
# Out:
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=1, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=2, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=3, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=4, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=0, multiplier=5, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=1, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=2, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=3, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=4, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=1, multiplier=5, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=1, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=2, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=3, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=4, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.08, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.08, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.09, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.09, run=1
# Running simulation with params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.1, run=1
# Results collected for params: pop_size=3000, stay=1, rec_cost=2, multiplier=5, rec_rate=0.1, run=1
# Running simulation with params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.01, run=1
# Results collected for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.01, run=1
# Running simulation with params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.02, run=1
# Results collected for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.02, run=1
# Running simulation with params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.03, run=1
# Results collected for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.03, run=1
# Running simulation with params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.04, run=1
# Results collected for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.04, run=1
# Running simulation with params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.05, run=1
# Results collected for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.05, run=1
# Running simulation with params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.06, run=1
# Results collected for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.06, run=1
# Running simulation with params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.07, run=1
# Results collected for params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.07, run=1
# Running simulation with params: pop_size=3000, stay=2, rec_cost=0, multiplier=1, rec_rate=0.08, run=1
# ...
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.07, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.07, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.08, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.08, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.09, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.09, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.1, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=2, rec_rate=0.1, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.01, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.01, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.02, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.02, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.03, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.03, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.04, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.04, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.05, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.05, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.06, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.06, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.07, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.07, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.08, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.08, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.09, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.09, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.1, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=3, rec_rate=0.1, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.01, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.01, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.02, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.02, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.03, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.03, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.04, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.04, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.05, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.05, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.06, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.06, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.07, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.07, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.08, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.08, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.09, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.09, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.1, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=4, rec_rate=0.1, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.01, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.01, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.02, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.02, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.03, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.03, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.04, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.04, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.05, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.05, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.06, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.06, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.07, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.07, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.08, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.08, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.09, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.09, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.1, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=1, multiplier=5, rec_rate=0.1, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.01, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.01, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.02, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.02, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.03, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.03, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.04, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.04, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.04, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.05, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.05, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.05, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.06, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.06, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.06, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.07, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.07, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.07, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.08, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.08, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.08, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.09, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.09, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.09, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.1, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.1, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=1, rec_rate=0.1, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.01, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.01, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.01, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.02, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.02, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.02, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.03, run=1
# Completed simulation for params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.03, run=1
# Results collected for params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.03, run=1
# Running simulation with params: pop_size=5000, stay=2, rec_cost=2, multiplier=2, rec_rate=0.04, run=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 47
#      31 sim = Sim(
#      32     start_energy=10,
#      33     population_size=pop_size,
#    (...)
#      43     max_y=5
#      44 )
#      46 # Run the simulation for 500 generations
# ---> 47 sim.simulate(10)  # 500 gens for full simulation
#      48 print(f"Completed simulation for params: pop_size={pop_size}, stay={stay}, rec_cost={rec_cost}, multiplier={multiplier}, rec_rate={rec_rate}, run={run+1}")
#      50 # Collect the results
#
# Cell In[5], line 184, in Sim.simulate(self, gens)
#     181 def simulate(self, gens):
#     182     #print("starting simulation")
#     183     for g in np.arange(gens):
# --> 184         self.simulate_gen(g)
#     185         if len(self.bacteria) == 0:
#     186             #print("all dead")
#     187             break
#
# Cell In[5], line 83, in Sim.simulate_gen(self, gen)
#      81     return bac
#      82 # apply update_fitness function to all bacteria
# ---> 83 self.bacteria = list(map(update_fitness, self.bacteria))
#      85 # bacteria die if energy is < 0
#      86 alive_bac = []  # to store bacteria that are alive
#
# Cell In[5], line 74, in Sim.simulate_gen.<locals>.update_fitness(bac)
#      70 self.bacteria = list(map(benefit, self.bacteria, [(self.num_coop * self.multiplier) / len(self.bacteria)]
#      71                          * len(self.bacteria)))
#      73 # cells lose energy
# ---> 74 def update_fitness(bac):
#      75     # random energy decrease
#      76     if np.random.choice(2, 1) == 1:
#      77         bac.energy -= 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Simulation graphics

# %%
# TODO: plot data + show simulation graphics for each independent simulation - AP
# TODO: create graphics for findings accross all simulations using data from dictionary - AP

# %% [markdown]
# # Modifying the ABM

# %%
# TODO: possibly add another factor to the simulation or another proccess to take place in each gen

# %% [markdown]
# # Simulating *in vitro* data

# %%
# TODO: generate simulations that match in vivo data
# TODO: plot data + show simulation graphics for each independent simulation
